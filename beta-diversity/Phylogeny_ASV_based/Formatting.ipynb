# %%
import pandas as pd

# Load the CSV file (samples as rows, ASVs as columns)
df = pd.read_csv('cleaned_asv_reads.csv')

# Transpose the DataFrame so that ASVs are rows and samples are columns
df_transposed = df.T

# Save the transposed DataFrame as TSV
df_transposed.to_csv('cleaned_asv_reads_transposed.tsv', sep='\t')

# %%
df
# Out:
#      d0ab2c15400fe710288526c9a33083fb  21b04aaabca0f92a5ba0a0b2eaa31aea  \
# 0                                 391                               694
# 1                                2782                              3982
# 2                                 754                              1524
# 3                                2547                              3013
# 4                                 243                                48
# ..                                ...                               ...
# 306                              2258                                 0
# 307                               703                               277
# 308                               974                              2522
# 309                               816                              2435
# 310                              1275                                 0
#
#      0b0a4bdddb823efeb9984bf862fe81f8  c13359a9f895b1a2b9fcf49ceaea0e8a  \
# ...
